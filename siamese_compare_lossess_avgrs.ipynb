# %% [markdown]
# # Image similarity estimation using a Siamese Network with a contrastive loss
#
# **Author:** Mehdi<br>
# **Date created:** 2021/05/06<br>
# **Last modified:** 2022/09/10<br>
# **Description:** Similarity learning using a siamese network trained with a contrastive loss.

# %% [markdown]
# ## Introduction
#
# [Siamese Networks](https://en.wikipedia.org/wiki/Siamese_neural_network)
# are neural networks which share weights between two or more sister networks,
# each producing embedding vectors of its respective inputs.
#
# In supervised similarity learning, the networks are then trained to maximize the
# contrast (distance) between embeddings of inputs of different classes, while minimizing the distance between
# embeddings of similar classes, resulting in embedding spaces that reflect
# the class segmentation of the training inputs.

# %% [markdown]
# ## Setup

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import pandas as pd
import os
from emnist import extract_training_samples

import zipfile
import shutil
from typing import Tuple, List
from shutil import copyfile

# Data Imports
from tqdm import tqdm
from glob import glob
from tensorflow import data as tfd
from tensorflow import image as tfi

# Data Visualization
#import plotly.express as px
#import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import clear_output as cls
import PIL
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.utils.vis_utils import plot_model
# Out:
# 2023-07-10 20:05:22.742171: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-10 20:05:22.744070: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-10 20:05:22.779489: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-10 20:05:22.780250: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 20:05:23.401727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras import backend as K
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 42

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_22337/3033196493.py:21: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %% [markdown]
# ## Hyperparameters

# %%
EPOCHS = 100
BATCH_SIZE = 32
margin = 1  # Margin for contrastive loss.
DIMENSION = 20

# %%
# Constants
IMAGE_SIZE = 150 # size of the input image
NUM_CLASSES = 9 # number of classes at the dataset
SPLIT_SIZE = .9 # Define proportion of images used for training

# Random Seed
RANDOM_SEED = 42 # set random seed for reproducibility
tf.random.set_seed(RANDOM_SEED) # set random seed for TensorFlow
np.random.seed(RANDOM_SEED) # set random seed for NumPy

# %%
#Load Data
ORIGINAL_TRAIN_DIR = "avgrs_img/train"
ORIGINAL_TEST_DIR = "avgrs_img/test"

# %% [markdown]
# https://www.tensorflow.org/tutorials/load_data/images
#
# https://stackoverflow.com/questions/50992702/how-to-format-x-and-y-data-from-imagedatagenerator-in-keras

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  ORIGINAL_TRAIN_DIR,
  color_mode="grayscale", 
  seed=123,
  image_size=(IMAGE_SIZE, IMAGE_SIZE),
  batch_size=205,
  )
# Out:
# Found 205 files belonging to 3 classes.

# %%
class_names_train = train_ds.class_names
print(class_names_train)
# Out:
# ['chris_evans', 'chris_hemsworth', 'mark_ruffalo']

# %%
X_train = []
y_train = []
for X, Y in train_ds:
   X_train = np.append(X_train, X)
   y_train = np.append(y_train, Y)
X_train = X_train.astype(int)
y_train = y_train.astype(int)
# Out:
# 2023-07-10 20:05:31.286119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [205]
# 	 [[{{node Placeholder/_0}}]]
# 2023-07-10 20:05:31.286397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [205]
# 	 [[{{node Placeholder/_0}}]]

# %%
X_train = X_train.reshape(-1, IMAGE_SIZE, IMAGE_SIZE)
print(X_train.shape)
# Out:
# (205, 150, 150)

# %%
print(np.unique(y_train))
# Out:
# [0 1 2]

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  ORIGINAL_TEST_DIR,
  color_mode="grayscale", 
  seed=123,
  image_size=(IMAGE_SIZE, IMAGE_SIZE),
  batch_size=63)
# Out:
# Found 63 files belonging to 5 classes.

# %%
class_names_test = test_ds.class_names
print(class_names_test)
# Out:
# ['chris_evans', 'chris_hemsworth', 'mark_ruffalo', 'robert_downey_jr', 'scarlett_johansson']

# %%
X_test = []
y_test = []
for X, Y in test_ds:
   X_test = np.append(X_test, X)
   y_test = np.append(y_test, Y)
X_test = X_test.astype(int)
y_test = y_test.astype(int)
# Out:
# 2023-07-10 20:05:31.728885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [63]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-10 20:05:31.729188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [63]
# 	 [[{{node Placeholder/_4}}]]

# %%
X_test = X_test.reshape(-1, IMAGE_SIZE, IMAGE_SIZE)
print(X_test.shape)
# Out:
# (63, 150, 150)

# %%
print(y_train.shape)
# Out:
# (205,)

# %%
print(np.unique(y_test))
# Out:
# [0 1 2 3 4]

# %% [markdown]
# ## Create pairs of images
#
# We will train the model to differentiate between digits of different classes. For
# example, digit `0` needs to be differentiated from the rest of the
# digits (`1` through `9`), digit `1` - from `0` and `2` through `9`, and so on.
# To carry this out, we will select N random images from class A (for example,
# for digit `0`) and pair them with N random images from another class B
# (for example, for digit `1`). Then, we can repeat this process for all classes
# of digits (until digit `9`). Once we have paired digit `0` with other digits,
# we can repeat this process for the remaining classes for the rest of the digits
# (from `1` until `9`).

# %%
def make_pairs(x, y):
    """Creates a tuple containing image pairs with corresponding label.

    Arguments:
        x: List containing images, each index in this list corresponds to one image.
        y: List containing labels, each label with datatype of `int`.

    Returns:
        Tuple containing two numpy arrays as (pairs_of_samples, labels),
        where pairs_of_samples' shape is (2len(x), 2,n_features_dims) and
        labels are a binary array of shape (2len(x)).
    """

    num_classes = max(y) + 1
    min_value = min(y)
    digit_indices = [np.where(y == i)[0] for i in range(min_value, num_classes)]
    
    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1-min_value])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

        # add a non-matching example
        label2 = random.randint(0,len(np.unique((y)))-1)
        while label2 == label1: 
            label2 = random.randint(0,len(np.unique((y)))-1)


        idx2 = random.choice(digit_indices[label2])
   
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

    return np.array(pairs), np.array(labels).astype("float32")

# %%
# make train pairs
pairs_train, labels_train = make_pairs(X_train, y_train)

# make test pairs
pairs_test, labels_test = make_pairs(X_test, y_test)

# %% [markdown]
# We get:
#
# **pairs_train.shape = (60000, 2, 28, 28)**
#
# - We have 60,000 pairs
# - Each pair contains 2 images
# - Each image has shape `(28, 28)`

# %% [markdown]
# Split the training pairs

# %%
x_train_1 = pairs_train[:, 0]  # x_train_1.shape is (60000, 28, 28)
x_train_2 = pairs_train[:, 1]

# %% [markdown]
# Split the test pairs

# %%
x_test_1 = pairs_test[:, 0]  # x_test_1.shape = (20000, 28, 28)
x_test_2 = pairs_test[:, 1]

# %% [markdown]
# ## Visualize pairs and their labels

# %%
def visualize(pairs, labels, to_show=6, num_col=3, predictions=None, test=False):
    """Creates a plot of pairs and labels, and prediction if it's test dataset.

    Arguments:
        pairs: Numpy Array, of pairs to visualize, having shape
               (Number of pairs, 2, 28, 28).
        to_show: Int, number of examples to visualize (default is 6)
                `to_show` must be an integral multiple of `num_col`.
                 Otherwise it will be trimmed if it is greater than num_col,
                 and incremented if if it is less then num_col.
        num_col: Int, number of images in one row - (default is 3)
                 For test and train respectively, it should not exceed 3 and 7.
        predictions: Numpy Array of predictions with shape (to_show, 1) -
                     (default is None)
                     Must be passed when test=True.
        test: Boolean telling whether the dataset being visualized is
              train dataset or test dataset - (default False).

    Returns:
        None.
    """

    # Define num_row
    # If to_show % num_col != 0
    #    trim to_show,
    #       to trim to_show limit num_row to the point where
    #       to_show % num_col == 0
    #
    # If to_show//num_col == 0
    #    then it means num_col is greater then to_show
    #    increment to_show
    #       to increment to_show set num_row to 1
    num_row = to_show // num_col if to_show // num_col != 0 else 1

    # `to_show` must be an integral multiple of `num_col`
    #  we found num_row and we have num_col
    #  to increment or decrement to_show
    #  to make it integral multiple of `num_col`
    #  simply set it equal to num_row * num_col
    to_show = num_row * num_col

    # Plot the images
    fig, axes = plt.subplots(num_row, num_col, figsize=(5, 5))
    for i in range(to_show):

        # If the number of rows is 1, the axes array is one-dimensional
        if num_row == 1:
            ax = axes[i % num_col]
        else:
            ax = axes[i // num_col, i % num_col]

        ax.imshow(tf.concat([pairs[i][0], pairs[i][1]], axis=1), cmap="gray")
        ax.set_axis_off()
        if test:
            ax.set_title("True: {} | Pred: {:.5f}".format(labels[i], predictions[i][0]))
        else:
            ax.set_title("Label: {}".format(labels[i]))
    if test:
        plt.tight_layout(rect=(0, 0, 1.9, 1.9), w_pad=0.0)
    else:
        plt.tight_layout(rect=(0, 0, 1.5, 1.5))
    plt.show()

# %% [markdown]
# Inspect training pairs

# %%
visualize(pairs_train[:-1], labels_train[:-1], to_show=4, num_col=4)

# %% [markdown]
# Inspect test pairs

# %%
visualize(pairs_test[:-1], labels_test[:-1], to_show=4, num_col=4)

# %% [markdown]
# ## Define the model
#
# There are two input layers, each leading to its own network, which
# produces embeddings. A `Lambda` layer then merges them using an
# [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) and the
# merged output is fed to the final network.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10,
                              monitor='val_loss',
                              mode='min',
                              verbose = 1,
                              restore_best_weights=True)
callback=[early_stopping]

# %%
# CONTRASTIVE LOSS
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))


input = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x = tf.keras.layers.BatchNormalization()(input)
x = layers.Conv2D(32, (3,3), activation="relu")(x)
x = layers.AveragePooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(32, (3,3), activation="relu")(x)
x = layers.AveragePooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(DIMENSION, activation="relu")(x)
embedding_network = keras.Model(input, x)


input_1 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = layers.Lambda(euclidean_distance)([tower_1, tower_2])
normal_layer = tf.keras.layers.BatchNormalization()(merge_layer)
output_layer = layers.Dense(1, activation="sigmoid")(normal_layer)

# define model for each loss function
siamese1 = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %%
# DICE LOSS

# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))


input2 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x2 = tf.keras.layers.BatchNormalization()(input2)
x2 = layers.Conv2D(32, (3,3), activation="relu")(x2)
x2 = layers.AveragePooling2D(pool_size=(2, 2))(x2)
x2 = layers.Conv2D(32, (3,3), activation="relu")(x2)
x2 = layers.AveragePooling2D(pool_size=(2, 2))(x2)
x2 = layers.Flatten()(x2)
x2 = layers.Dense(32, activation="relu")(x2)
x2 = layers.Dense(DIMENSION, activation="relu")(x2)
embedding_network_2 = keras.Model(input2, x2)


input_1_2 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2_2 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1_2 = embedding_network_2(input_1_2)
tower_2_2 = embedding_network_2(input_2_2)

merge_layer_2 = layers.Lambda(euclidean_distance)([tower_1_2, tower_2_2])
normal_layer_2 = tf.keras.layers.BatchNormalization()(merge_layer_2)
output_layer_2 = layers.Dense(1, activation="sigmoid")(normal_layer_2)
siamese2 = keras.Model(inputs=[input_1_2, input_2_2], outputs=output_layer_2)

# %%
# BCE LOSS

# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))


input3 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x3 = tf.keras.layers.BatchNormalization()(input3)
x3 = layers.Conv2D(32, (3,3), activation="relu")(x3)
x3 = layers.AveragePooling2D(pool_size=(2, 2))(x3)
x3 = layers.Conv2D(32, (3,3), activation="relu")(x3)
x3 = layers.AveragePooling2D(pool_size=(2, 2))(x3)
x3 = layers.Flatten()(x3)
x3 = layers.Dense(32, activation="relu")(x3)
x3 = layers.Dense(DIMENSION, activation="relu")(x3)
embedding_network_3 = keras.Model(input3, x3)

input_1_3 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2_3 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1_3 = embedding_network_3(input_1_3)
tower_2_3 = embedding_network_3(input_2_3)

merge_layer_3 = layers.Lambda(euclidean_distance)([tower_1_3, tower_2_3])
normal_layer_3 = tf.keras.layers.BatchNormalization()(merge_layer_3)
output_layer_3 = layers.Dense(1, activation="sigmoid")(normal_layer_3)
siamese3 = keras.Model(inputs=[input_1_3, input_2_3], outputs=output_layer_3)

# %%
# BCE + DICE LOSS

# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))


input4 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x4 = tf.keras.layers.BatchNormalization()(input4)
x4 = layers.Conv2D(32, (3,3), activation="relu")(x4)
x4 = layers.AveragePooling2D(pool_size=(2, 2))(x4)
x4 = layers.Conv2D(32, (3,3), activation="relu")(x4)
x4 = layers.AveragePooling2D(pool_size=(2, 2))(x4)
x4 = layers.Flatten()(x4)
x4 = layers.Dense(32, activation="relu")(x4)
x4 = layers.Dense(DIMENSION, activation="relu")(x4)
embedding_network_4 = keras.Model(input4, x4)


input_1_4 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2_4 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1_4 = embedding_network_4(input_1_4)
tower_2_4 = embedding_network_4(input_2_4)

merge_layer_4 = layers.Lambda(euclidean_distance)([tower_1_4, tower_2_4])
normal_layer_4 = tf.keras.layers.BatchNormalization()(merge_layer_4)
output_layer_4 = layers.Dense(1, activation="sigmoid")(normal_layer_4)
siamese4 = keras.Model(inputs=[input_1_4, input_2_4], outputs=output_layer_4)

# %%
# MSE + KLD + Ranking Loss

# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

input5 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x5 = tf.keras.layers.BatchNormalization()(input5)
x5 = layers.Conv2D(32, (3,3), activation="relu")(x5)
x5 = layers.AveragePooling2D(pool_size=(2, 2))(x5)
x5 = layers.Conv2D(32, (3,3), activation="relu")(x5)
x5 = layers.AveragePooling2D(pool_size=(2, 2))(x5)
x5 = layers.Flatten()(x5)
x5 = layers.Dense(32, activation="relu")(x5)
x5 = layers.Dense(DIMENSION, activation="relu")(x5)
embedding_network5 = keras.Model(input5, x5)


input_1_5 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2_5 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1_5 = embedding_network5(input_1_5)
tower_2_5 = embedding_network5(input_2_5)

merge_layer_5 = layers.Lambda(euclidean_distance)([tower_1_5, tower_2_5])
normal_layer_5 = tf.keras.layers.BatchNormalization()(merge_layer_5)
output_layer_5 = layers.Dense(1, activation="sigmoid")(normal_layer_5)

# define model for each loss function
siamese5 = keras.Model(inputs=[input_1_5, input_2_5], outputs=output_layer_5)

# %%
# Hinge loss

def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

input6 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
x6 = tf.keras.layers.BatchNormalization()(input5)
x6 = layers.Conv2D(32, (3,3), activation="relu")(x6)
x6 = layers.AveragePooling2D(pool_size=(2, 2))(x6)
x6 = layers.Conv2D(32, (3,3), activation="relu")(x6)
x6 = layers.AveragePooling2D(pool_size=(2, 2))(x6)
x6 = layers.Flatten()(x6)
x6 = layers.Dense(32, activation="relu")(x6)
x6 = layers.Dense(DIMENSION, activation="relu")(x6)
embedding_network6 = keras.Model(input5, x6)


input_1_6 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))
input_2_6 = layers.Input((IMAGE_SIZE, IMAGE_SIZE, 1))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1_6 = embedding_network6(input_1_6)
tower_2_6 = embedding_network6(input_2_6)

merge_layer_6 = layers.Lambda(euclidean_distance)([tower_1_6, tower_2_6])
normal_layer_6 = tf.keras.layers.BatchNormalization()(merge_layer_6)
output_layer_6 = layers.Dense(1, activation="sigmoid")(normal_layer_6)

# define model for each loss function
siamese6 = keras.Model(inputs=[input_1_6, input_2_6], outputs=output_layer_6)

# %% [markdown]
# ## Define the contrastive Loss

# %%
def contrastive_loss(margin=1):
    """Provides 'contrastive_loss' an enclosing scope with variable 'margin'.

    Arguments:
        margin: Integer, defines the baseline for distance for which pairs
                should be classified as dissimilar. - (default is 1).

    Returns:
        'contrastive_loss' function with data ('margin') attached.
    """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the contrastive loss.

        Arguments:
            y_true: List of labels, each label is of type float32.
            y_pred: List of predictions of same length as of y_true,
                    each label is of type float32.

        Returns:
            A tensor containing contrastive loss as floating point value.
        """

        square_pred = tf.math.square(y_pred)
        margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
        return tf.math.reduce_mean(
            (1 - y_true) * square_pred + (y_true) * margin_square
        )   

        """
        square_pred = tf.math.square(y_pred)
        margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
        return tf.math.reduce_mean(
            (1 - y_true) * margin_square + (y_true) * square_pred
        )
        """

    return contrastive_loss

# %% [markdown]
# ## Define the Dice Loss
# Code: https://stackoverflow.com/questions/72195156/correct-implementation-of-dice-loss-in-tensorflow-keras
#
# ![Dice Loss](./img/Dice_Loss.png)

# %%
# Dice Loss
def dice_loss(margin=1): #ignore margin

    smooth=1e-6

    def dice_coef(y_true, y_pred, smooth=100):        
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
        return dice
    
    def dice_coef_loss(y_true, y_pred):
        return 1 - dice_coef(y_true, y_pred)
    
    return dice_coef_loss

# %% [markdown]
# ## Define the Binary Cross Entropy Loss
# Code: https://www.kaggle.com/code/bigironsphere/loss-function-library-keras-pytorch/notebook
#
# ![BCE Loss](./img/BCE_Loss.png)

# %%
# BCE_Loss
def BCE_loss(margin=1): #ignore margin

    def binary_cross_entropy_loss(y_true, y_pred):
        BCE =  K.binary_crossentropy(y_true, y_pred)
        return BCE
    
    return binary_cross_entropy_loss

# %% [markdown]
# ## Define the BCE + Dice Loss
# Paper: https://ieeexplore.ieee.org/abstract/document/10023508?casa_token=_zhnKjSaYgYAAAAA:zZ0oLIx6Yoc56OeYEdvdJfwA0FLyQyhg3NNmd8YOUTzPLLgn5hK8ZoJ4UUAwH_9Dn55YLj2fQbk
# Code: https://www.kaggle.com/code/bigironsphere/loss-function-library-keras-pytorch/notebook
#
# ![Dice Loss](./img/BCE_Loss.png)
# ![Dice Loss](./img/Dice_Loss.png)
# ![Dice Loss](./img/BCE_Dice_Loss.png)

# %%
# BCE_Dice_Loss
def BCE_dice_loss(margin=1): #ignore margin

    smooth=1e-6

    def dice_coef_loss(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
        
        return dice

    
    def binary_cross_entropy_loss(y_true, y_pred):
        BCE =  K.binary_crossentropy(y_true, y_pred)
        return BCE
    

    def BCE_dice_coef_loss(y_true, y_pred):
        dice_loss = 1 - dice_coef_loss(y_true, y_pred)
        BCE =  binary_cross_entropy_loss(y_true, y_pred)
        Dice_BCE = BCE + dice_loss
        return Dice_BCE
    
    return BCE_dice_coef_loss

# %% [markdown]
# ## Define the MSE + KLD + Ranking Loss
# https://datascience.stackexchange.com/questions/9262/calculating-kl-divergence-in-python
#
# Original Paper: https://dl.acm.org/doi/pdf/10.1145/3597434

# %%
# MSE + KLD + Ranking Loss
def MSE_BKLD_Loss():

    def b_kld_l(y_true, y_pred):
        epsilon = 0.00001

        Q = y_true+epsilon
        Q_hut = y_pred+epsilon
        QQ = (Q + Q_hut)/2

        divergence_Q = K.sum(Q*K.log(Q/QQ))
        divergence_Q_hut = K.sum(Q_hut*K.log(Q/QQ))
        divergence = divergence_Q + divergence_Q_hut
        return 1-divergence
    
    def mse_l(y_true, y_pred):
        mse = tf.keras.losses.mean_squared_error(y_true, y_pred)
        return mse
    
    def mse_bkld_l(y_true, y_pred):
        mse = mse_l(y_true, y_pred)
        bkld = b_kld_l(y_true, y_pred)
        mse_bkld = mse+bkld
        return mse_bkld
    
    return mse_bkld_l

# %% [markdown]
# ## Define Hinge Loss

# %%
# Use Keras Hinge Loss

# %% [markdown]
# ## Compile the model with the contrastive loss

# %%
siamese1.compile(loss=contrastive_loss(margin=margin), optimizer="Adam", metrics=["accuracy"])
siamese1.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_3 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  model (Functional)             (None, 20)           1337368     ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  batch_normalization_1 (BatchNo  (None, 1)           4           ['lambda[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 1)            2           ['batch_normalization_1[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile the model with the dice loss

# %%
siamese2.compile(loss=dice_loss(margin=margin), optimizer="Adam", metrics=["accuracy"])
siamese2.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_6 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  model_2 (Functional)           (None, 20)           1337368     ['input_5[0][0]',
#                                                                   'input_6[0][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['model_2[0][0]',
#                                                                   'model_2[1][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1)           4           ['lambda_1[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 1)            2           ['batch_normalization_3[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile the model with the BCE loss

# %%
siamese3.compile(loss=BCE_loss(margin=margin), optimizer="Adam", metrics=["accuracy"])
siamese3.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_9 (InputLayer)           [(None, 150, 150, 1  0           []
#                                 )]
#
#  model_4 (Functional)           (None, 20)           1337368     ['input_8[0][0]',
#                                                                   'input_9[0][0]']
#
#  lambda_2 (Lambda)              (None, 1)            0           ['model_4[0][0]',
#                                                                   'model_4[1][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1)           4           ['lambda_2[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 1)            2           ['batch_normalization_5[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile the model with the BCE + dice loss

# %%
siamese4.compile(loss=BCE_dice_loss(margin=margin), optimizer="Adam", metrics=["accuracy"])
siamese4.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_12 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  model_6 (Functional)           (None, 20)           1337368     ['input_11[0][0]',
#                                                                   'input_12[0][0]']
#
#  lambda_3 (Lambda)              (None, 1)            0           ['model_6[0][0]',
#                                                                   'model_6[1][0]']
#
#  batch_normalization_7 (BatchNo  (None, 1)           4           ['lambda_3[0][0]']
#  rmalization)
#
#  dense_11 (Dense)               (None, 1)            2           ['batch_normalization_7[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile the model with the MSE + KLD + Ranking Loss

# %%
siamese5.compile(loss=MSE_BKLD_Loss(), optimizer="Adam", metrics=["accuracy"])
siamese5.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_15 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  model_8 (Functional)           (None, 20)           1337368     ['input_14[0][0]',
#                                                                   'input_15[0][0]']
#
#  lambda_4 (Lambda)              (None, 1)            0           ['model_8[0][0]',
#                                                                   'model_8[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 1)           4           ['lambda_4[0][0]']
#  rmalization)
#
#  dense_14 (Dense)               (None, 1)            2           ['batch_normalization_9[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile the model with the Hinge loss

# %%
siamese6.compile(loss=tf.keras.losses.Hinge(), optimizer="Adam", metrics=["accuracy"])
siamese6.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  input_18 (InputLayer)          [(None, 150, 150, 1  0           []
#                                 )]
#
#  model_10 (Functional)          (None, 20)           1337368     ['input_17[0][0]',
#                                                                   'input_18[0][0]']
#
#  lambda_5 (Lambda)              (None, 1)            0           ['model_10[0][0]',
#                                                                   'model_10[1][0]']
#
#  batch_normalization_11 (BatchN  (None, 1)           4           ['lambda_5[0][0]']
#  ormalization)
#
#  dense_17 (Dense)               (None, 1)            2           ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 1,337,374
# Trainable params: 1,337,370
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the models

# %%
# Contrastive Loss
history1 = siamese1.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 7s 531ms/step - loss: 0.2982 - accuracy: 0.4878 - val_loss: 0.5045 - val_accuracy: 0.4756
# Epoch 2/100
# 11/11 [==============================] - 6s 523ms/step - loss: 0.2680 - accuracy: 0.5518 - val_loss: 0.4999 - val_accuracy: 0.4756
# Epoch 3/100
# 11/11 [==============================] - 6s 495ms/step - loss: 0.2508 - accuracy: 0.5854 - val_loss: 0.4863 - val_accuracy: 0.4756
# Epoch 4/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.2435 - accuracy: 0.5854 - val_loss: 0.4701 - val_accuracy: 0.4756
# Epoch 5/100
# 11/11 [==============================] - 5s 490ms/step - loss: 0.2264 - accuracy: 0.6463 - val_loss: 0.4688 - val_accuracy: 0.4756
# Epoch 6/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.2169 - accuracy: 0.6372 - val_loss: 0.4109 - val_accuracy: 0.4512
# Epoch 7/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.1951 - accuracy: 0.7043 - val_loss: 0.4071 - val_accuracy: 0.4512
# Epoch 8/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.1830 - accuracy: 0.7652 - val_loss: 0.3738 - val_accuracy: 0.4512
# Epoch 9/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.1707 - accuracy: 0.7744 - val_loss: 0.3283 - val_accuracy: 0.4268
# Epoch 10/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.1573 - accuracy: 0.8201 - val_loss: 0.3366 - val_accuracy: 0.4512
# Epoch 11/100
# 11/11 [==============================] - 5s 487ms/step - loss: 0.1531 - accuracy: 0.8476 - val_loss: 0.3599 - val_accuracy: 0.4268
# Epoch 12/100
# 11/11 [==============================] - 5s 500ms/step - loss: 0.1367 - accuracy: 0.8659 - val_loss: 0.3284 - val_accuracy: 0.4756
# Epoch 13/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.1262 - accuracy: 0.8841 - val_loss: 0.3155 - val_accuracy: 0.4756
# Epoch 14/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.1215 - accuracy: 0.9146 - val_loss: 0.3300 - val_accuracy: 0.4512
# Epoch 15/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.1199 - accuracy: 0.9055 - val_loss: 0.3190 - val_accuracy: 0.4146
# Epoch 16/100
# 11/11 [==============================] - 5s 497ms/step - loss: 0.1170 - accuracy: 0.9116 - val_loss: 0.3392 - val_accuracy: 0.4512
# Epoch 17/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.1034 - accuracy: 0.9177 - val_loss: 0.3147 - val_accuracy: 0.4512
# Epoch 18/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0926 - accuracy: 0.9695 - val_loss: 0.3252 - val_accuracy: 0.4512
# Epoch 19/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.0942 - accuracy: 0.9634 - val_loss: 0.3507 - val_accuracy: 0.4634
# Epoch 20/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.0908 - accuracy: 0.9543 - val_loss: 0.3358 - val_accuracy: 0.4512
# Epoch 21/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0830 - accuracy: 0.9634 - val_loss: 0.3513 - val_accuracy: 0.4146
# Epoch 22/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.0741 - accuracy: 0.9787 - val_loss: 0.3502 - val_accuracy: 0.4390
# Epoch 23/100
# 11/11 [==============================] - 6s 499ms/step - loss: 0.0700 - accuracy: 0.9878 - val_loss: 0.3474 - val_accuracy: 0.4878
# Epoch 24/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.0666 - accuracy: 0.9909 - val_loss: 0.3472 - val_accuracy: 0.4512
# Epoch 25/100
# 11/11 [==============================] - 6s 500ms/step - loss: 0.0705 - accuracy: 0.9787 - val_loss: 0.3629 - val_accuracy: 0.5000
# Epoch 26/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0639 - accuracy: 0.9878 - val_loss: 0.3485 - val_accuracy: 0.4390
# Epoch 27/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9939Restoring model weights from the end of the best epoch: 17.
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0583 - accuracy: 0.9939 - val_loss: 0.3617 - val_accuracy: 0.4634
# Epoch 27: early stopping

# %%
# Dice Loss
history2 = siamese2.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 7s 514ms/step - loss: 0.1183 - accuracy: 0.4878 - val_loss: 0.0979 - val_accuracy: 0.5244
# Epoch 2/100
# 11/11 [==============================] - 5s 497ms/step - loss: 0.1164 - accuracy: 0.5091 - val_loss: 0.0988 - val_accuracy: 0.5244
# Epoch 3/100
# 11/11 [==============================] - 5s 497ms/step - loss: 0.1145 - accuracy: 0.5183 - val_loss: 0.0996 - val_accuracy: 0.5366
# Epoch 4/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.1127 - accuracy: 0.5305 - val_loss: 0.1005 - val_accuracy: 0.5488
# Epoch 5/100
# 11/11 [==============================] - 6s 500ms/step - loss: 0.1071 - accuracy: 0.5854 - val_loss: 0.0999 - val_accuracy: 0.5488
# Epoch 6/100
# 11/11 [==============================] - 6s 500ms/step - loss: 0.1004 - accuracy: 0.6524 - val_loss: 0.0964 - val_accuracy: 0.5610
# Epoch 7/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0932 - accuracy: 0.7134 - val_loss: 0.1008 - val_accuracy: 0.5610
# Epoch 8/100
# 11/11 [==============================] - 5s 497ms/step - loss: 0.0861 - accuracy: 0.7591 - val_loss: 0.0900 - val_accuracy: 0.6098
# Epoch 9/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0805 - accuracy: 0.7957 - val_loss: 0.0883 - val_accuracy: 0.6463
# Epoch 10/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0745 - accuracy: 0.8201 - val_loss: 0.0865 - val_accuracy: 0.6463
# Epoch 11/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0712 - accuracy: 0.8750 - val_loss: 0.0844 - val_accuracy: 0.7439
# Epoch 12/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.0651 - accuracy: 0.9055 - val_loss: 0.0795 - val_accuracy: 0.7439
# Epoch 13/100
# 11/11 [==============================] - 6s 511ms/step - loss: 0.0609 - accuracy: 0.9207 - val_loss: 0.0807 - val_accuracy: 0.7561
# Epoch 14/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.0591 - accuracy: 0.9268 - val_loss: 0.0805 - val_accuracy: 0.7805
# Epoch 15/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0564 - accuracy: 0.9329 - val_loss: 0.0764 - val_accuracy: 0.7439
# Epoch 16/100
# 11/11 [==============================] - 6s 500ms/step - loss: 0.0533 - accuracy: 0.9543 - val_loss: 0.0712 - val_accuracy: 0.7805
# Epoch 17/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0494 - accuracy: 0.9695 - val_loss: 0.0747 - val_accuracy: 0.7683
# Epoch 18/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0477 - accuracy: 0.9756 - val_loss: 0.0751 - val_accuracy: 0.7805
# Epoch 19/100
# 11/11 [==============================] - 5s 499ms/step - loss: 0.0453 - accuracy: 0.9787 - val_loss: 0.0749 - val_accuracy: 0.8049
# Epoch 20/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0442 - accuracy: 0.9878 - val_loss: 0.0777 - val_accuracy: 0.7805
# Epoch 21/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0420 - accuracy: 0.9878 - val_loss: 0.0762 - val_accuracy: 0.7805
# Epoch 22/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0400 - accuracy: 0.9939 - val_loss: 0.0763 - val_accuracy: 0.7805
# Epoch 23/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0392 - accuracy: 0.9848 - val_loss: 0.0722 - val_accuracy: 0.7683
# Epoch 24/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.0374 - accuracy: 0.9970 - val_loss: 0.0754 - val_accuracy: 0.7805
# Epoch 25/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0368 - accuracy: 0.9970 - val_loss: 0.0725 - val_accuracy: 0.7683
# Epoch 26/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 16.
# 11/11 [==============================] - 5s 499ms/step - loss: 0.0353 - accuracy: 0.9970 - val_loss: 0.0715 - val_accuracy: 0.7805
# Epoch 26: early stopping

# %%
# BCE Loss
history3 = siamese3.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 7s 507ms/step - loss: 0.9295 - accuracy: 0.5000 - val_loss: 11.8683 - val_accuracy: 0.4756
# Epoch 2/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.8259 - accuracy: 0.5457 - val_loss: 7.0926 - val_accuracy: 0.4756
# Epoch 3/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.7676 - accuracy: 0.6006 - val_loss: 4.6298 - val_accuracy: 0.4756
# Epoch 4/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.7699 - accuracy: 0.5884 - val_loss: 4.4667 - val_accuracy: 0.4878
# Epoch 5/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.7185 - accuracy: 0.6220 - val_loss: 2.1746 - val_accuracy: 0.4756
# Epoch 6/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6839 - accuracy: 0.6311 - val_loss: 1.8534 - val_accuracy: 0.5000
# Epoch 7/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.5811 - accuracy: 0.7226 - val_loss: 1.1793 - val_accuracy: 0.4512
# Epoch 8/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.5228 - accuracy: 0.7530 - val_loss: 1.2286 - val_accuracy: 0.4268
# Epoch 9/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.4682 - accuracy: 0.8262 - val_loss: 1.0297 - val_accuracy: 0.4024
# Epoch 10/100
# 11/11 [==============================] - 5s 497ms/step - loss: 0.4653 - accuracy: 0.8110 - val_loss: 1.0126 - val_accuracy: 0.4634
# Epoch 11/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.4260 - accuracy: 0.8445 - val_loss: 1.0464 - val_accuracy: 0.4756
# Epoch 12/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.4077 - accuracy: 0.8598 - val_loss: 0.9815 - val_accuracy: 0.4756
# Epoch 13/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.3912 - accuracy: 0.8902 - val_loss: 0.9266 - val_accuracy: 0.4512
# Epoch 14/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.3669 - accuracy: 0.9055 - val_loss: 0.9104 - val_accuracy: 0.4390
# Epoch 15/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.3520 - accuracy: 0.9268 - val_loss: 0.9161 - val_accuracy: 0.4512
# Epoch 16/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.3302 - accuracy: 0.9451 - val_loss: 0.9205 - val_accuracy: 0.4268
# Epoch 17/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.3143 - accuracy: 0.9512 - val_loss: 0.9495 - val_accuracy: 0.4146
# Epoch 18/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.3101 - accuracy: 0.9482 - val_loss: 0.9664 - val_accuracy: 0.3780
# Epoch 19/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.2993 - accuracy: 0.9634 - val_loss: 0.9833 - val_accuracy: 0.3902
# Epoch 20/100
# 11/11 [==============================] - 5s 488ms/step - loss: 0.3013 - accuracy: 0.9604 - val_loss: 0.9762 - val_accuracy: 0.4024
# Epoch 21/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.2880 - accuracy: 0.9756 - val_loss: 1.0133 - val_accuracy: 0.4024
# Epoch 22/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.2697 - accuracy: 0.9878 - val_loss: 1.0114 - val_accuracy: 0.4268
# Epoch 23/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.2623 - accuracy: 0.9817 - val_loss: 1.0082 - val_accuracy: 0.4268
# Epoch 24/100
# 11/11 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9848Restoring model weights from the end of the best epoch: 14.
# 11/11 [==============================] - 5s 489ms/step - loss: 0.2513 - accuracy: 0.9848 - val_loss: 1.0592 - val_accuracy: 0.3659
# Epoch 24: early stopping

# %%
# BCE + Dice Loss
history4 = siamese4.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 7s 509ms/step - loss: 1.2773 - accuracy: 0.5000 - val_loss: 7.3013 - val_accuracy: 0.5244
# Epoch 2/100
# 11/11 [==============================] - 6s 514ms/step - loss: 1.2169 - accuracy: 0.5488 - val_loss: 2.4365 - val_accuracy: 0.5244
# Epoch 3/100
# 11/11 [==============================] - 6s 546ms/step - loss: 1.1325 - accuracy: 0.6006 - val_loss: 2.5885 - val_accuracy: 0.5244
# Epoch 4/100
# 11/11 [==============================] - 6s 541ms/step - loss: 1.0680 - accuracy: 0.6555 - val_loss: 1.6183 - val_accuracy: 0.5122
# Epoch 5/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.9790 - accuracy: 0.7226 - val_loss: 1.3395 - val_accuracy: 0.5366
# Epoch 6/100
# 11/11 [==============================] - 6s 538ms/step - loss: 0.8992 - accuracy: 0.7835 - val_loss: 1.1002 - val_accuracy: 0.5854
# Epoch 7/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.8448 - accuracy: 0.8079 - val_loss: 1.0090 - val_accuracy: 0.6220
# Epoch 8/100
# 11/11 [==============================] - 6s 531ms/step - loss: 0.8328 - accuracy: 0.8293 - val_loss: 0.9623 - val_accuracy: 0.6585
# Epoch 9/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.7959 - accuracy: 0.8384 - val_loss: 0.9683 - val_accuracy: 0.6585
# Epoch 10/100
# 11/11 [==============================] - 6s 545ms/step - loss: 0.7212 - accuracy: 0.9116 - val_loss: 0.9116 - val_accuracy: 0.6951
# Epoch 11/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.6844 - accuracy: 0.9238 - val_loss: 0.9035 - val_accuracy: 0.7073
# Epoch 12/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.6512 - accuracy: 0.9604 - val_loss: 0.8909 - val_accuracy: 0.7805
# Epoch 13/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.6297 - accuracy: 0.9604 - val_loss: 0.8494 - val_accuracy: 0.8049
# Epoch 14/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.6018 - accuracy: 0.9726 - val_loss: 0.8313 - val_accuracy: 0.7805
# Epoch 15/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5875 - accuracy: 0.9726 - val_loss: 0.8263 - val_accuracy: 0.8171
# Epoch 16/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5582 - accuracy: 0.9787 - val_loss: 0.8116 - val_accuracy: 0.8049
# Epoch 17/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5311 - accuracy: 0.9909 - val_loss: 0.8149 - val_accuracy: 0.8171
# Epoch 18/100
# 11/11 [==============================] - 6s 516ms/step - loss: 0.5271 - accuracy: 0.9817 - val_loss: 0.8094 - val_accuracy: 0.8171
# Epoch 19/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.5290 - accuracy: 0.9787 - val_loss: 0.8094 - val_accuracy: 0.8415
# Epoch 20/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.5190 - accuracy: 0.9848 - val_loss: 0.8149 - val_accuracy: 0.7927
# Epoch 21/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.4877 - accuracy: 0.9909 - val_loss: 0.8093 - val_accuracy: 0.8171
# Epoch 22/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.4684 - accuracy: 0.9970 - val_loss: 0.7671 - val_accuracy: 0.8293
# Epoch 23/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.4548 - accuracy: 1.0000 - val_loss: 0.7691 - val_accuracy: 0.8415
# Epoch 24/100
# 11/11 [==============================] - 6s 511ms/step - loss: 0.4435 - accuracy: 0.9970 - val_loss: 0.7404 - val_accuracy: 0.8537
# Epoch 25/100
# 11/11 [==============================] - 6s 525ms/step - loss: 0.4338 - accuracy: 0.9970 - val_loss: 0.7362 - val_accuracy: 0.8537
# Epoch 26/100
# 11/11 [==============================] - 6s 505ms/step - loss: 0.4201 - accuracy: 0.9970 - val_loss: 0.7199 - val_accuracy: 0.8415
# Epoch 27/100
# 11/11 [==============================] - 5s 487ms/step - loss: 0.4074 - accuracy: 0.9939 - val_loss: 0.7262 - val_accuracy: 0.8415
# Epoch 28/100
# 11/11 [==============================] - 5s 486ms/step - loss: 0.4286 - accuracy: 0.9939 - val_loss: 0.7235 - val_accuracy: 0.8415
# Epoch 29/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.3734 - accuracy: 1.0000 - val_loss: 0.7024 - val_accuracy: 0.8537
# Epoch 30/100
# 11/11 [==============================] - 6s 526ms/step - loss: 0.3958 - accuracy: 1.0000 - val_loss: 0.7075 - val_accuracy: 0.8415
# Epoch 31/100
# 11/11 [==============================] - 6s 545ms/step - loss: 0.3709 - accuracy: 1.0000 - val_loss: 0.6931 - val_accuracy: 0.8415
# Epoch 32/100
# 11/11 [==============================] - 6s 505ms/step - loss: 0.3622 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.8537
# Epoch 33/100
# 11/11 [==============================] - 5s 488ms/step - loss: 0.3512 - accuracy: 0.9970 - val_loss: 0.6894 - val_accuracy: 0.8415
# Epoch 34/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.3489 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.8415
# Epoch 35/100
# 11/11 [==============================] - 6s 541ms/step - loss: 0.3500 - accuracy: 1.0000 - val_loss: 0.6804 - val_accuracy: 0.8780
# Epoch 36/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.3406 - accuracy: 1.0000 - val_loss: 0.6864 - val_accuracy: 0.8537
# Epoch 37/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.3104 - accuracy: 1.0000 - val_loss: 0.6871 - val_accuracy: 0.8659
# Epoch 38/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.3095 - accuracy: 0.9970 - val_loss: 0.6647 - val_accuracy: 0.8415
# Epoch 39/100
# 11/11 [==============================] - 6s 536ms/step - loss: 0.3134 - accuracy: 1.0000 - val_loss: 0.6767 - val_accuracy: 0.8659
# Epoch 40/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.2956 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.8537
# Epoch 41/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.2890 - accuracy: 0.9970 - val_loss: 0.6658 - val_accuracy: 0.8537
# Epoch 42/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.2787 - accuracy: 0.9970 - val_loss: 0.6463 - val_accuracy: 0.8537
# Epoch 43/100
# 11/11 [==============================] - 6s 525ms/step - loss: 0.2820 - accuracy: 1.0000 - val_loss: 0.6377 - val_accuracy: 0.8659
# Epoch 44/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.2661 - accuracy: 0.9970 - val_loss: 0.6485 - val_accuracy: 0.8659
# Epoch 45/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.2703 - accuracy: 1.0000 - val_loss: 0.6352 - val_accuracy: 0.8780
# Epoch 46/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.2465 - accuracy: 1.0000 - val_loss: 0.6451 - val_accuracy: 0.8537
# Epoch 47/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.2420 - accuracy: 1.0000 - val_loss: 0.6502 - val_accuracy: 0.8293
# Epoch 48/100
# 11/11 [==============================] - 5s 495ms/step - loss: 0.2414 - accuracy: 1.0000 - val_loss: 0.6366 - val_accuracy: 0.8659
# Epoch 49/100
# 11/11 [==============================] - 5s 490ms/step - loss: 0.2316 - accuracy: 1.0000 - val_loss: 0.6338 - val_accuracy: 0.8659
# Epoch 50/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.2276 - accuracy: 1.0000 - val_loss: 0.6252 - val_accuracy: 0.8659
# Epoch 51/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.2248 - accuracy: 1.0000 - val_loss: 0.6325 - val_accuracy: 0.8659
# Epoch 52/100
# 11/11 [==============================] - 6s 546ms/step - loss: 0.2033 - accuracy: 1.0000 - val_loss: 0.6295 - val_accuracy: 0.8537
# Epoch 53/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.2440 - accuracy: 1.0000 - val_loss: 0.6224 - val_accuracy: 0.8659
# Epoch 54/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.1982 - accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.8537
# Epoch 55/100
# 11/11 [==============================] - 6s 538ms/step - loss: 0.2212 - accuracy: 1.0000 - val_loss: 0.6140 - val_accuracy: 0.8659
# Epoch 56/100
# 11/11 [==============================] - 6s 536ms/step - loss: 0.1963 - accuracy: 1.0000 - val_loss: 0.6212 - val_accuracy: 0.8659
# Epoch 57/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.2047 - accuracy: 1.0000 - val_loss: 0.6149 - val_accuracy: 0.8415
# Epoch 58/100
# 11/11 [==============================] - 6s 523ms/step - loss: 0.1841 - accuracy: 1.0000 - val_loss: 0.6042 - val_accuracy: 0.8415
# Epoch 59/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.1849 - accuracy: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.8415
# Epoch 60/100
# 11/11 [==============================] - 6s 506ms/step - loss: 0.1893 - accuracy: 1.0000 - val_loss: 0.5970 - val_accuracy: 0.8659
# Epoch 61/100
# 11/11 [==============================] - 6s 504ms/step - loss: 0.2063 - accuracy: 1.0000 - val_loss: 0.5871 - val_accuracy: 0.8537
# Epoch 62/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.1860 - accuracy: 1.0000 - val_loss: 0.5903 - val_accuracy: 0.8415
# Epoch 63/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.1621 - accuracy: 1.0000 - val_loss: 0.5883 - val_accuracy: 0.8537
# Epoch 64/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.1677 - accuracy: 1.0000 - val_loss: 0.5800 - val_accuracy: 0.8537
# Epoch 65/100
# 11/11 [==============================] - 6s 510ms/step - loss: 0.2166 - accuracy: 0.9878 - val_loss: 0.5662 - val_accuracy: 0.8659
# Epoch 66/100
# 11/11 [==============================] - 6s 543ms/step - loss: 0.3010 - accuracy: 0.9573 - val_loss: 0.8789 - val_accuracy: 0.7561
# Epoch 67/100
# 11/11 [==============================] - 6s 546ms/step - loss: 0.2799 - accuracy: 0.9756 - val_loss: 0.8510 - val_accuracy: 0.7561
# Epoch 68/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.2428 - accuracy: 0.9909 - val_loss: 0.6953 - val_accuracy: 0.7927
# Epoch 69/100
# 11/11 [==============================] - 6s 529ms/step - loss: 0.1810 - accuracy: 1.0000 - val_loss: 0.6674 - val_accuracy: 0.7927
# Epoch 70/100
# 11/11 [==============================] - 6s 528ms/step - loss: 0.1672 - accuracy: 0.9970 - val_loss: 0.6068 - val_accuracy: 0.8049
# Epoch 71/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.1637 - accuracy: 0.9939 - val_loss: 0.6527 - val_accuracy: 0.8171
# Epoch 72/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.1591 - accuracy: 0.9970 - val_loss: 0.6961 - val_accuracy: 0.7927
# Epoch 73/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.1637 - accuracy: 0.9970 - val_loss: 0.6702 - val_accuracy: 0.8171
# Epoch 74/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.1631 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 0.8415
# Epoch 75/100
# 11/11 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 65.
# 11/11 [==============================] - 6s 538ms/step - loss: 0.1396 - accuracy: 0.9970 - val_loss: 0.6288 - val_accuracy: 0.8293
# Epoch 75: early stopping

# %%
# MSE + KLD + Ranking Loss
history5 = siamese5.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs= EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 8s 559ms/step - loss: 74.8347 - accuracy: 0.4970 - val_loss: -4.3079 - val_accuracy: 0.4756
# Epoch 2/100
# 11/11 [==============================] - 6s 539ms/step - loss: 72.4337 - accuracy: 0.5213 - val_loss: 1.1615 - val_accuracy: 0.4756
# Epoch 3/100
# 11/11 [==============================] - 5s 493ms/step - loss: 70.0734 - accuracy: 0.5610 - val_loss: 8.8801 - val_accuracy: 0.4756
# Epoch 4/100
# 11/11 [==============================] - 5s 488ms/step - loss: 67.7537 - accuracy: 0.6037 - val_loss: 13.2576 - val_accuracy: 0.4512
# Epoch 5/100
# 11/11 [==============================] - 5s 490ms/step - loss: 63.0009 - accuracy: 0.6494 - val_loss: 18.7494 - val_accuracy: 0.4634
# Epoch 6/100
# 11/11 [==============================] - 5s 492ms/step - loss: 62.2493 - accuracy: 0.6616 - val_loss: 32.0958 - val_accuracy: 0.4634
# Epoch 7/100
# 11/11 [==============================] - 5s 491ms/step - loss: 59.2201 - accuracy: 0.7195 - val_loss: 34.5421 - val_accuracy: 0.4634
# Epoch 8/100
# 11/11 [==============================] - 5s 499ms/step - loss: 55.5207 - accuracy: 0.7409 - val_loss: 42.1148 - val_accuracy: 0.4512
# Epoch 9/100
# 11/11 [==============================] - 6s 507ms/step - loss: 52.3476 - accuracy: 0.8049 - val_loss: 51.1544 - val_accuracy: 0.4390
# Epoch 10/100
# 11/11 [==============================] - 5s 493ms/step - loss: 49.7033 - accuracy: 0.8018 - val_loss: 50.4198 - val_accuracy: 0.4512
# Epoch 11/100
# 11/11 [==============================] - ETA: 0s - loss: 47.8917 - accuracy: 0.8262Restoring model weights from the end of the best epoch: 1.
# 11/11 [==============================] - 5s 487ms/step - loss: 47.8917 - accuracy: 0.8262 - val_loss: 53.0258 - val_accuracy: 0.4390
# Epoch 11: early stopping

# %%
# Hinge Loss
history6 = siamese6.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_split=0.2,
    shuffle=True,
    callbacks=callback,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 8s 577ms/step - loss: 0.9965 - accuracy: 0.4878 - val_loss: 0.9817 - val_accuracy: 0.5244
# Epoch 2/100
# 11/11 [==============================] - 6s 501ms/step - loss: 0.9831 - accuracy: 0.5274 - val_loss: 0.9837 - val_accuracy: 0.5366
# Epoch 3/100
# 11/11 [==============================] - 5s 490ms/step - loss: 0.9737 - accuracy: 0.5762 - val_loss: 0.9738 - val_accuracy: 0.5366
# Epoch 4/100
# 11/11 [==============================] - 6s 538ms/step - loss: 0.9559 - accuracy: 0.5488 - val_loss: 0.9701 - val_accuracy: 0.5366
# Epoch 5/100
# 11/11 [==============================] - 6s 542ms/step - loss: 0.9374 - accuracy: 0.5976 - val_loss: 0.9731 - val_accuracy: 0.5244
# Epoch 6/100
# 11/11 [==============================] - 6s 543ms/step - loss: 0.8958 - accuracy: 0.6921 - val_loss: 0.9668 - val_accuracy: 0.5488
# Epoch 7/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.8778 - accuracy: 0.7378 - val_loss: 0.9311 - val_accuracy: 0.6098
# Epoch 8/100
# 11/11 [==============================] - 6s 536ms/step - loss: 0.8649 - accuracy: 0.7348 - val_loss: 0.9199 - val_accuracy: 0.6220
# Epoch 9/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.8315 - accuracy: 0.8079 - val_loss: 0.9128 - val_accuracy: 0.7073
# Epoch 10/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.8051 - accuracy: 0.8659 - val_loss: 0.8971 - val_accuracy: 0.7561
# Epoch 11/100
# 11/11 [==============================] - 6s 536ms/step - loss: 0.7771 - accuracy: 0.9116 - val_loss: 0.8773 - val_accuracy: 0.8293
# Epoch 12/100
# 11/11 [==============================] - 6s 518ms/step - loss: 0.7679 - accuracy: 0.9024 - val_loss: 0.8755 - val_accuracy: 0.7927
# Epoch 13/100
# 11/11 [==============================] - 5s 487ms/step - loss: 0.7483 - accuracy: 0.9360 - val_loss: 0.8754 - val_accuracy: 0.7317
# Epoch 14/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.7327 - accuracy: 0.9634 - val_loss: 0.8669 - val_accuracy: 0.7439
# Epoch 15/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.7176 - accuracy: 0.9787 - val_loss: 0.8749 - val_accuracy: 0.7073
# Epoch 16/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.7048 - accuracy: 0.9848 - val_loss: 0.8514 - val_accuracy: 0.7317
# Epoch 17/100
# 11/11 [==============================] - 6s 542ms/step - loss: 0.6897 - accuracy: 0.9878 - val_loss: 0.8603 - val_accuracy: 0.7195
# Epoch 18/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.6909 - accuracy: 0.9817 - val_loss: 0.8187 - val_accuracy: 0.8293
# Epoch 19/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.6881 - accuracy: 0.9817 - val_loss: 0.8095 - val_accuracy: 0.8659
# Epoch 20/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.6782 - accuracy: 0.9939 - val_loss: 0.8097 - val_accuracy: 0.8049
# Epoch 21/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.6705 - accuracy: 0.9909 - val_loss: 0.8193 - val_accuracy: 0.8049
# Epoch 22/100
# 11/11 [==============================] - 6s 527ms/step - loss: 0.6636 - accuracy: 0.9939 - val_loss: 0.8355 - val_accuracy: 0.7561
# Epoch 23/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6595 - accuracy: 0.9939 - val_loss: 0.8080 - val_accuracy: 0.8049
# Epoch 24/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6508 - accuracy: 0.9970 - val_loss: 0.7948 - val_accuracy: 0.8293
# Epoch 25/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.6477 - accuracy: 1.0000 - val_loss: 0.7934 - val_accuracy: 0.8415
# Epoch 26/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.6422 - accuracy: 1.0000 - val_loss: 0.7763 - val_accuracy: 0.8659
# Epoch 27/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.6368 - accuracy: 1.0000 - val_loss: 0.7670 - val_accuracy: 0.8537
# Epoch 28/100
# 11/11 [==============================] - 6s 542ms/step - loss: 0.6418 - accuracy: 0.9878 - val_loss: 0.7772 - val_accuracy: 0.8293
# Epoch 29/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.6773 - accuracy: 0.9512 - val_loss: 0.7744 - val_accuracy: 0.8171
# Epoch 30/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.6734 - accuracy: 0.9543 - val_loss: 0.7513 - val_accuracy: 0.8537
# Epoch 31/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6452 - accuracy: 0.9848 - val_loss: 0.7508 - val_accuracy: 0.8171
# Epoch 32/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.6355 - accuracy: 0.9878 - val_loss: 0.7292 - val_accuracy: 0.8780
# Epoch 33/100
# 11/11 [==============================] - 6s 543ms/step - loss: 0.6254 - accuracy: 1.0000 - val_loss: 0.7235 - val_accuracy: 0.8659
# Epoch 34/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6227 - accuracy: 0.9970 - val_loss: 0.7072 - val_accuracy: 0.8780
# Epoch 35/100
# 11/11 [==============================] - 5s 494ms/step - loss: 0.6214 - accuracy: 1.0000 - val_loss: 0.6941 - val_accuracy: 0.8902
# Epoch 36/100
# 11/11 [==============================] - 6s 511ms/step - loss: 0.6167 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.8902
# Epoch 37/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.6028 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.8902
# Epoch 38/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.6003 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.8902
# Epoch 39/100
# 11/11 [==============================] - 6s 506ms/step - loss: 0.6028 - accuracy: 1.0000 - val_loss: 0.6903 - val_accuracy: 0.9024
# Epoch 40/100
# 11/11 [==============================] - 6s 505ms/step - loss: 0.5952 - accuracy: 1.0000 - val_loss: 0.6863 - val_accuracy: 0.8902
# Epoch 41/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.5935 - accuracy: 1.0000 - val_loss: 0.6837 - val_accuracy: 0.9024
# Epoch 42/100
# 11/11 [==============================] - 5s 498ms/step - loss: 0.5879 - accuracy: 1.0000 - val_loss: 0.6833 - val_accuracy: 0.9024
# Epoch 43/100
# 11/11 [==============================] - 6s 538ms/step - loss: 0.5903 - accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.9024
# Epoch 44/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.5840 - accuracy: 1.0000 - val_loss: 0.6707 - val_accuracy: 0.9024
# Epoch 45/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.5865 - accuracy: 1.0000 - val_loss: 0.6716 - val_accuracy: 0.9024
# Epoch 46/100
# 11/11 [==============================] - 6s 507ms/step - loss: 0.5766 - accuracy: 1.0000 - val_loss: 0.6677 - val_accuracy: 0.9268
# Epoch 47/100
# 11/11 [==============================] - 6s 547ms/step - loss: 0.5756 - accuracy: 1.0000 - val_loss: 0.6660 - val_accuracy: 0.9146
# Epoch 48/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5765 - accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.9268
# Epoch 49/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5738 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.9146
# Epoch 50/100
# 11/11 [==============================] - 6s 541ms/step - loss: 0.5726 - accuracy: 1.0000 - val_loss: 0.6554 - val_accuracy: 0.9268
# Epoch 51/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.5723 - accuracy: 1.0000 - val_loss: 0.6667 - val_accuracy: 0.9146
# Epoch 52/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5633 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.9268
# Epoch 53/100
# 11/11 [==============================] - 6s 530ms/step - loss: 0.5803 - accuracy: 1.0000 - val_loss: 0.6575 - val_accuracy: 0.9146
# Epoch 54/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.5618 - accuracy: 1.0000 - val_loss: 0.6593 - val_accuracy: 0.9268
# Epoch 55/100
# 11/11 [==============================] - 6s 530ms/step - loss: 0.5703 - accuracy: 1.0000 - val_loss: 0.6539 - val_accuracy: 0.9146
# Epoch 56/100
# 11/11 [==============================] - 6s 531ms/step - loss: 0.5611 - accuracy: 1.0000 - val_loss: 0.6551 - val_accuracy: 0.9268
# Epoch 57/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.5648 - accuracy: 1.0000 - val_loss: 0.6583 - val_accuracy: 0.9268
# Epoch 58/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.5566 - accuracy: 1.0000 - val_loss: 0.6508 - val_accuracy: 0.9268
# Epoch 59/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.5572 - accuracy: 1.0000 - val_loss: 0.6482 - val_accuracy: 0.9268
# Epoch 60/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.5593 - accuracy: 1.0000 - val_loss: 0.6477 - val_accuracy: 0.9268
# Epoch 61/100
# 11/11 [==============================] - 5s 490ms/step - loss: 0.5655 - accuracy: 1.0000 - val_loss: 0.6544 - val_accuracy: 0.9268
# Epoch 62/100
# 11/11 [==============================] - 6s 511ms/step - loss: 0.5600 - accuracy: 1.0000 - val_loss: 0.6465 - val_accuracy: 0.9268
# Epoch 63/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.5504 - accuracy: 1.0000 - val_loss: 0.6462 - val_accuracy: 0.9268
# Epoch 64/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.5527 - accuracy: 1.0000 - val_loss: 0.6457 - val_accuracy: 0.9268
# Epoch 65/100
# 11/11 [==============================] - 6s 535ms/step - loss: 0.5673 - accuracy: 0.9878 - val_loss: 0.6981 - val_accuracy: 0.9024
# Epoch 66/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.6632 - accuracy: 0.9116 - val_loss: 0.8774 - val_accuracy: 0.6220
# Epoch 67/100
# 11/11 [==============================] - 6s 507ms/step - loss: 0.6427 - accuracy: 0.9238 - val_loss: 0.8037 - val_accuracy: 0.7317
# Epoch 68/100
# 11/11 [==============================] - 6s 505ms/step - loss: 0.6051 - accuracy: 0.9634 - val_loss: 0.7197 - val_accuracy: 0.8415
# Epoch 69/100
# 11/11 [==============================] - 6s 541ms/step - loss: 0.5746 - accuracy: 0.9939 - val_loss: 0.6922 - val_accuracy: 0.8659
# Epoch 70/100
# 11/11 [==============================] - 5s 493ms/step - loss: 0.5611 - accuracy: 0.9939 - val_loss: 0.6709 - val_accuracy: 0.8902
# Epoch 71/100
# 11/11 [==============================] - 5s 489ms/step - loss: 0.5536 - accuracy: 1.0000 - val_loss: 0.6683 - val_accuracy: 0.9146
# Epoch 72/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.5468 - accuracy: 1.0000 - val_loss: 0.6335 - val_accuracy: 0.9390
# Epoch 73/100
# 11/11 [==============================] - 5s 491ms/step - loss: 0.5472 - accuracy: 1.0000 - val_loss: 0.6293 - val_accuracy: 0.9390
# Epoch 74/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.5464 - accuracy: 1.0000 - val_loss: 0.6249 - val_accuracy: 0.9390
# Epoch 75/100
# 11/11 [==============================] - 6s 541ms/step - loss: 0.5398 - accuracy: 1.0000 - val_loss: 0.6247 - val_accuracy: 0.9390
# Epoch 76/100
# 11/11 [==============================] - 6s 536ms/step - loss: 0.5432 - accuracy: 1.0000 - val_loss: 0.6272 - val_accuracy: 0.9390
# Epoch 77/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5354 - accuracy: 1.0000 - val_loss: 0.6296 - val_accuracy: 0.9390
# Epoch 78/100
# 11/11 [==============================] - 6s 533ms/step - loss: 0.5372 - accuracy: 1.0000 - val_loss: 0.6201 - val_accuracy: 0.9512
# Epoch 79/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5399 - accuracy: 1.0000 - val_loss: 0.6173 - val_accuracy: 0.9512
# Epoch 80/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.5423 - accuracy: 1.0000 - val_loss: 0.6116 - val_accuracy: 0.9512
# Epoch 81/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.5373 - accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.9512
# Epoch 82/100
# 11/11 [==============================] - 6s 531ms/step - loss: 0.5316 - accuracy: 1.0000 - val_loss: 0.6097 - val_accuracy: 0.9512
# Epoch 83/100
# 11/11 [==============================] - 6s 509ms/step - loss: 0.5375 - accuracy: 1.0000 - val_loss: 0.6089 - val_accuracy: 0.9512
# Epoch 84/100
# 11/11 [==============================] - 5s 486ms/step - loss: 0.5327 - accuracy: 1.0000 - val_loss: 0.6089 - val_accuracy: 0.9390
# Epoch 85/100
# 11/11 [==============================] - 6s 543ms/step - loss: 0.5314 - accuracy: 1.0000 - val_loss: 0.6065 - val_accuracy: 0.9390
# Epoch 86/100
# 11/11 [==============================] - 6s 540ms/step - loss: 0.5325 - accuracy: 1.0000 - val_loss: 0.6043 - val_accuracy: 0.9390
# Epoch 87/100
# 11/11 [==============================] - 6s 495ms/step - loss: 0.5428 - accuracy: 1.0000 - val_loss: 0.6010 - val_accuracy: 0.9390
# Epoch 88/100
# 11/11 [==============================] - 5s 492ms/step - loss: 0.5310 - accuracy: 1.0000 - val_loss: 0.6016 - val_accuracy: 0.9390
# Epoch 89/100
# 11/11 [==============================] - 5s 496ms/step - loss: 0.5317 - accuracy: 1.0000 - val_loss: 0.6002 - val_accuracy: 0.9390
# Epoch 90/100
# 11/11 [==============================] - 5s 490ms/step - loss: 0.5273 - accuracy: 1.0000 - val_loss: 0.5988 - val_accuracy: 0.9390
# Epoch 91/100
# 11/11 [==============================] - 6s 544ms/step - loss: 0.5293 - accuracy: 1.0000 - val_loss: 0.5988 - val_accuracy: 0.9390
# Epoch 92/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.5308 - accuracy: 1.0000 - val_loss: 0.5987 - val_accuracy: 0.9390
# Epoch 93/100
# 11/11 [==============================] - 6s 542ms/step - loss: 0.5319 - accuracy: 1.0000 - val_loss: 0.5978 - val_accuracy: 0.9390
# Epoch 94/100
# 11/11 [==============================] - 6s 532ms/step - loss: 0.5314 - accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.9390
# Epoch 95/100
# 11/11 [==============================] - 6s 531ms/step - loss: 0.5247 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.9390
# Epoch 96/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5280 - accuracy: 1.0000 - val_loss: 0.5965 - val_accuracy: 0.9390
# Epoch 97/100
# 11/11 [==============================] - 6s 539ms/step - loss: 0.5263 - accuracy: 1.0000 - val_loss: 0.5965 - val_accuracy: 0.9390
# Epoch 98/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5282 - accuracy: 1.0000 - val_loss: 0.5946 - val_accuracy: 0.9390
# Epoch 99/100
# 11/11 [==============================] - 6s 534ms/step - loss: 0.5247 - accuracy: 1.0000 - val_loss: 0.5926 - val_accuracy: 0.9390
# Epoch 100/100
# 11/11 [==============================] - 6s 537ms/step - loss: 0.5263 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.9390

# %% [markdown]
# ## Visualize results

# %%
def plt_metric(history, metric, title, has_valid=True, x = 0, y = 0):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    axs[x, y].plot(history[metric])
    if has_valid:
        axs[x, y].plot(history["val_" + metric])
        axs[x, y].legend(["train", "validation"], loc="upper left")
    axs[x, y].set_title(title)
    
    for ax in axs.flat:
        ax.set(xlabel="epoch")
        
    axs.flat[0].set(ylabel="accuracy")
    axs.flat[6].set(ylabel="accuracy")
    axs.flat[3].set(ylabel="loss")
    axs.flat[9].set(ylabel="loss")
    
    # Hide x labels and tick labels for top plots and y ticks for right plots.
    #for ax in axs.flat:
    #    ax.label_outer()
        
    axs[x,y].set_xlim([0, 100])

# %%
fig, axs = plt.subplots(4, 3)

fig.set_figheight(20)
fig.set_figwidth(20)

# Plot the accuracy of contrastive loss
plt_metric(history=history1.history, metric="accuracy", title="Model accuracy of CL", x=0 ,y=0)

# Plot the contrastive loss
plt_metric(history=history1.history, metric="loss", title="Contrastive Loss", x=1 ,y=0)

# Plot the accuracy of dice loss
plt_metric(history=history2.history, metric="accuracy", title="Model accuracy of DL",x=0 ,y=1)

# Plot the dice loss
plt_metric(history=history2.history, metric="loss", title="Dice Loss", x=1 ,y=1)

# Plot the accuracy of BCE loss
plt_metric(history=history3.history, metric="accuracy", title="Model accuracy of BCEL",x=0 ,y=2)

# Plot the BCE loss
plt_metric(history=history3.history, metric="loss", title="BCE Loss", x=1 ,y=2)

# Plot the accuracy of BCE dice loss
plt_metric(history=history4.history, metric="accuracy", title="Model accuracy of BCEDL", x=2 ,y=0)

# Plot the BCE dice loss
plt_metric(history=history4.history, metric="loss", title="BCE Dice Loss", x=3 ,y=0)

# Plot the accuracy of MSE + KLS + ranking loss
plt_metric(history=history5.history, metric="accuracy", title="Model accuracy of MSE_KLD_Rank", x=2 ,y=1)

# Plot the MSE + KLD + ranking loss
plt_metric(history=history5.history, metric="loss", title="MSE_KLD_Rank Loss", x=3 ,y=1)

# Plot the accuracy of hinge loss
plt_metric(history=history6.history, metric="accuracy", title="Model accuracy of Hinge", x=2 ,y=2)

# Plot the hinge loss
plt_metric(history=history6.history, metric="loss", title="Hinge Loss", x=3 ,y=2)

# %%
def plt_metric_train(history, metric, title, has_valid=True, x = 0, y = 0):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    axs[x,y].plot(history[metric])
    
    axs[x,y].legend(["CL","DL","BCEL","BCEDL","Hinge"], loc="upper left")
    
    axs[x,y].set_title(title)
    
    for ax in axs.flat:
        ax.set(xlabel="epoch")
    
    # Hide x labels and tick labels for top plots and y ticks for right plots.
    #for ax in axs.flat:
    #    ax.label_outer()  
    
    axs[x,y].set_xlim([0, 100])
            
def plt_metric_val(history, metric, title, has_valid=True, x = 0, y = 0):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    axs[x,y].plot(history["val_" + metric])
    
    axs[x,y].legend(["CL","DL","BCEL","BCEDL","Hinge"], loc="upper left")
    
    axs[x,y].set_title(title)
        
    for ax in axs.flat:
        ax.set(xlabel="epoch")
                        
    # Hide x labels and tick labels for top plots and y ticks for right plots.
    #for ax in axs.flat:
    #    ax.label_outer()
    
    axs[x,y].set_xlim([0, 100])

# %%
fig, axs = plt.subplots(2,2)

fig.set_figheight(20)
fig.set_figwidth(20)

# Plot the accuracy of contrastive loss
plt_metric_train(history=history1.history, metric="accuracy", title="Train Accuracy", x=0 ,y=0)

# Plot the accuracy of dice loss
plt_metric_train(history=history2.history, metric="accuracy", title="Train Accuracy",x=0 ,y=0)

# Plot the accuracy of BCE loss
plt_metric_train(history=history3.history, metric="accuracy", title="Train Accuracy",x=0 ,y=0)

# Plot the accuracy of BCE dice loss
plt_metric_train(history=history4.history, metric="accuracy", title="Train Accuracy", x=0 ,y=0)

# Plot the accuracy of MSE + KLS + ranking loss
# plt_metric_train(history=history5.history, metric="accuracy", title="Train Accuracy", x=0 ,y=0)

# Plot the accuracy of hinge loss
plt_metric_train(history=history6.history, metric="accuracy", title="Train Accuracy", x=0 ,y=0)


# Plot the contrastive loss
plt_metric_train(history=history1.history, metric="loss", title="Train Loss", x=1 ,y=0)

# Plot the dice loss
plt_metric_train(history=history2.history, metric="loss", title="Train Loss", x=1 ,y=0)

# Plot the BCE loss
plt_metric_train(history=history3.history, metric="loss", title="Train Loss", x=1 ,y=0)

# Plot the BCE dice loss
plt_metric_train(history=history4.history, metric="loss", title="Train Loss", x=1 ,y=0)

# Plot the MSE + KLD + ranking loss
# plt_metric_train(history=history5.history, metric="loss", title="Train Loss", x=1 ,y=0)

# Plot the hinge loss
plt_metric_train(history=history6.history, metric="loss", title="Train Loss", x=1 ,y=0)


# Plot the accuracy of contrastive loss
plt_metric_val(history=history1.history, metric="accuracy", title="Validation Accuracy", x=0 ,y=1)

# Plot the accuracy of dice loss
plt_metric_val(history=history2.history, metric="accuracy", title="Validation Accuracy",x=0 ,y=1)

# Plot the accuracy of BCE loss
plt_metric_val(history=history3.history, metric="accuracy", title="Validation Accuracy",x=0 ,y=1)

# Plot the accuracy of BCE dice loss
plt_metric_val(history=history4.history, metric="accuracy", title="Validation Accuracy", x=0 ,y=1)

# Plot the accuracy of MSE + KLS + ranking loss
# plt_metric_val(history=history5.history, metric="accuracy", title="Validation Accuracy", x=0 ,y=1)

# Plot the accuracy of hinge loss
plt_metric_val(history=history6.history, metric="accuracy", title="Validation Accuracy", x=0 ,y=1)


# Plot the contrastive loss
plt_metric_val(history=history1.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# Plot the dice loss
plt_metric_val(history=history2.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# Plot the BCE loss
plt_metric_val(history=history3.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# Plot the BCE dice loss
plt_metric_val(history=history4.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# Plot the MSE + KLD + ranking loss
#plt_metric_val(history=history5.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# Plot the hinge loss
plt_metric_val(history=history6.history, metric="loss", title="Validation Loss", x=1 ,y=1)

# %% [markdown]
# ## Evaluate the model

# %%
results1 = siamese1.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results1)
# Out:
# 4/4 [==============================] - 0s 103ms/step - loss: 0.2892 - accuracy: 0.5317
# test loss, test acc: [0.2891952097415924, 0.5317460298538208]

# %%
results2 = siamese2.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results2)
# Out:
# 4/4 [==============================] - 0s 101ms/step - loss: 0.0982 - accuracy: 0.6825
# test loss, test acc: [0.09818441420793533, 0.682539701461792]

# %%
results3 = siamese3.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results3)
# Out:
# 4/4 [==============================] - 0s 103ms/step - loss: 0.8907 - accuracy: 0.5317
# test loss, test acc: [0.89069664478302, 0.5317460298538208]

# %%
results4 = siamese4.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results4)
# Out:
# 4/4 [==============================] - 0s 109ms/step - loss: 0.9325 - accuracy: 0.7222
# test loss, test acc: [0.9325498342514038, 0.7222222089767456]

# %%
results5 = siamese5.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results5)
# Out:
# 4/4 [==============================] - 0s 105ms/step - loss: -8.8145 - accuracy: 0.5000
# test loss, test acc: [-8.81445598602295, 0.5]

# %%
results6 = siamese6.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results6)
# Out:
# 4/4 [==============================] - 0s 102ms/step - loss: 0.7633 - accuracy: 0.7937
# test loss, test acc: [0.7632849216461182, 0.7936508059501648]

# %%
data = {'CL': results1[0], 'DL': results2[0], 'BCEL': results3[0],
        'BCDL': results4[0],'Hinge': results6[0]}
 
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize=(15, 10))
 
# creating the bar plot
plt.bar(courses, values)
 
plt.xlabel("Percent")
plt.ylabel("Different losses")
plt.title("Test loss")
plt.show()

data = {'CL': results1[1], 'DL': results2[1], 'BCEL': results3[1],
        'BCDL': results4[1],
        'Hinge': results6[1]}
 
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize=(15, 10))
 
# creating the bar plot
plt.bar(courses, values)
 
plt.xlabel("Percent")
plt.ylabel("Different Losses")
plt.title("Test accuracy")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, recall_score, precision_score, f1_score

# Evaluate the model on the test set
y_pred_cat1 = siamese1.predict([x_test_1, x_test_2])
y_pred1 = np.argmax(y_pred_cat1, axis=1)

report1 = classification_report(labels_test, y_pred1)
print(report1)
# Out:
# 4/4 [==============================] - 1s 100ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred_cat2 = siamese2.predict([x_test_1, x_test_2])
y_pred2 = np.argmax(y_pred_cat2, axis=1)

report2 = classification_report(labels_test, y_pred2)
print(report2)
# Out:
# 4/4 [==============================] - 1s 99ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred_cat3 = siamese4.predict([x_test_1, x_test_2])
y_pred3 = np.argmax(y_pred_cat3, axis=1)

report3 = classification_report(labels_test, y_pred3)
print(report3)
# Out:
# 4/4 [==============================] - 0s 87ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred_cat4 = siamese4.predict([x_test_1, x_test_2])
y_pred4 = np.argmax(y_pred_cat4, axis=1)

report4 = classification_report(labels_test, y_pred4)
print(report4)
# Out:
# 4/4 [==============================] - 0s 88ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred_cat5 = siamese5.predict([x_test_1, x_test_2])
y_pred5 = np.argmax(y_pred_cat5, axis=1)

report5 = classification_report(labels_test, y_pred5)
print(report5)
# Out:
# 4/4 [==============================] - 0s 93ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred_cat6 = siamese6.predict([x_test_1, x_test_2])
y_pred6 = np.argmax(y_pred_cat5, axis=1)

report6 = classification_report(labels_test, y_pred6)
print(report6)
# Out:
# 4/4 [==============================] - 0s 88ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        63
#          1.0       0.00      0.00      0.00        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nd/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_model (siamese1, show_shapes=True, to_file='model.png')

# %% [markdown]
# ## Visualize the predictions

# %%
predictions = siamese1.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions, test=True)
# Out:
# 4/4 [==============================] - 0s 85ms/step

# %%
predictions2 = siamese2.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions2, test=True)
# Out:
# 4/4 [==============================] - 0s 86ms/step

# %%
predictions3 = siamese3.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions3, test=True)
# Out:
# 4/4 [==============================] - 0s 86ms/step

# %%
predictions4 = siamese4.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions4, test=True)
# Out:
# 4/4 [==============================] - 0s 85ms/step

# %%
predictions5 = siamese5.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions5, test=True)
# Out:
# 4/4 [==============================] - 0s 85ms/step

# %%
predictions6 = siamese6.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=10, predictions=predictions6, test=True)
# Out:
# 4/4 [==============================] - 0s 85ms/step

# %% [markdown]
# ## Other possible loss functions

# %% [markdown]
# ### Cross Entropy with balance factor (2023)
# Paper:
# https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=10021880
#
# ### Join of MSE, bidirectional Kullback Leibler divergence and rank order of quality scores (2023)
# Paper:
# https://dl.acm.org/doi/abs/10.1145/3597434
#
# ### Multiple negative ranking loss (2022)
# Paper:
# https://arxiv.org/pdf/2203.14541.pdf
#
# original: https://arxiv.org/pdf/1705.00652.pdf
#
# ### Max margin hinge loss (2021)
# Paper:
# https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=9414458
#
# ### Softmax cross entropy loss (2018)
# Paper:
# https://www.researchgate.net/publication/326204812_Modeling_Contemporaneous_Basket_Sequences_with_Twin_Networks_for_Next-Item_Recommendation
